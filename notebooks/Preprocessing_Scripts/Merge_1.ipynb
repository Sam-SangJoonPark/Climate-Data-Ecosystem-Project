# %% [markdown]
# ## Merging

# %% [markdown]
# ## Tweaks:
# - 2023 cross walk
# - 2013 cross walk

# %%
crosswalk_version = 2023

# %%
import yaml
import pandas as pd

# Step 1: Load YAML
with open("../../config/merging.yaml", "r") as f:
    config = yaml.safe_load(f)

# Step 2: Select version and extract file names
file_list = config[crosswalk_version]['files']
join_keys = config[crosswalk_version]['join_keys']

# Step 3: Define data folder path
data_path = "../../data/interim/"
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Step 4: Load each CSV using the paths from the config
criteria_df = pd.read_csv(data_path + file_list["criteria"])
hazard_df   = pd.read_csv(data_path + file_list["hazard"])
migration_df= pd.read_csv(data_path + file_list["migration"])
housing_df  = pd.read_csv(data_path + file_list["housing"])
unemployment_df  = pd.read_csv(data_path + file_list["unemployment"])
residence_df = pd.read_csv(data_path + file_list["residence"])

# %%
join_keys
# Out:
# {'criteria': 'Crosswalk2023_CBSA Code',
#  'hazard': 'Crosswalk2023_CBSA Code',
#  'migration': 'Migration16to20_Metro Code of Geography A',
#  'housing': 'HousingPI25_GEOID',
#  'unemployment': 'Crosswalk2023_CBSA Code',
#  'residence': 'Current_Residence_Code'}

# %%
criteria_df.head(3)
# Out:
#    Crosswalk2023_CBSA Code Crosswalk2023_CBSA Title Crosswalk2023_State Name
# 0                    10180              Abilene, TX                    Texas
# 1                    10380            Aguadilla, PR              Puerto Rico
# 2                    10420                Akron, OH                     Ohio

# %%
hazard_df.head(3)
# Out:
#    Crosswalk2023_CBSA Code  NRI_AVLN_EALPE  NRI_CFLD_EALPE  NRI_CWAV_EALPE  \
# 0                  10100.0             0.0    0.000000e+00    2.164489e+06
# 1                  10140.0             0.0    2.331413e+07    0.000000e+00
# 2                  10180.0             0.0    0.000000e+00    4.854410e+05
#
#    NRI_ERQK_EALPE  NRI_HAIL_EALPE  NRI_HWAV_EALPE  NRI_HRCN_EALPE  \
# 0    6.357991e+03   187611.434808    4.347053e+05        0.000000
# 1    1.280793e+07      397.881741    2.055710e+03        0.000000
# 2    1.990667e+04   483001.071482    1.375110e+06     2751.963861
#
#    NRI_ISTM_EALPE  NRI_LNDS_EALPE  ...  NRI_RFLD_EXPB  NRI_SWND_EXPB  \
# 0   222528.920926     1065.074257  ...   6.505215e+08   1.397063e+10
# 1     1739.400614   122577.699905  ...   3.281721e+09   1.566485e+10
# 2   118521.393091    40474.255904  ...   4.136462e+09   3.170204e+10
#
#    NRI_TRND_EXPB  NRI_TSUN_EXPB  NRI_VLCN_EXPB  NRI_WFIR_EXPB  NRI_WNTW_EXPB  \
# 0   1.397063e+10   0.000000e+00            0.0   1.514336e+09   1.397063e+10
# 1   1.566485e+10   8.037370e+09            0.0   2.640196e+09   1.566485e+10
# 2   3.170204e+10   0.000000e+00            0.0   4.755646e+09   3.170204e+10
#
#    NRI_BUILDVALUE  NRI_POPULATION     NRI_AREA
# 0    1.397063e+10         42217.0  2911.111469
# 1    1.566485e+10         75462.0  2246.050928
# 2    3.170204e+10        176438.0  2785.545644
#
# [3 rows x 72 columns]

# %%
migration_df.head(3)
# Out:
#    Migration16to20_Metro Code of Geography A  \
# 0                                      10180
# 1                                      10380
# 2                                      10420
#
#    Migration16to20_A_Inflow_Estimate  Migration16to20_A_Outflow_Estimate  \
# 0                            14074.0                             12714.0
# 1                             3447.0                             11070.0
# 2                            29065.0                             29891.0
#
#    Migration16to20_A_NetMigration_Estimate  \
# 0                                   1360.0
# 1                                  -7623.0
# 2                                   -826.0
#
#    Migration16to20_A_GrossMigration_Estimate  Migration16to20_A_Inflow_MOE  \
# 0                                    26788.0                   1184.831634
# 1                                    14517.0                    639.049294
# 2                                    58956.0                   1763.152007
#
#    Migration16to20_A_Outflow_MOE  Migration16to20_A_NetMigration_MOE  \
# 0                    1675.577811                         2061.050218
# 1                    1348.850251                         1486.460225
# 2                    1855.395645                         2517.326161
#
#    Migration16to20_A_GrossMigration_MOE
# 0                           2043.932973
# 1                           1498.274674
# 2                           2601.782274

# %%
housing_df.head(3)
# Out:
#    HousingPI25_GEOID HousingPI25_Metro Area  HousingPI25_GEOID.1  \
# 0              10540             Albany, OR                10540
# 1              10180            Abilene, TX                10180
# 2              10500             Albany, GA                10500
#
#    HousingPI25_1980  HousingPI25_1981  HousingPI25_1982  HousingPI25_1983  \
# 0               3.2               2.9               2.8               2.8
# 1               3.1               2.9               2.9               2.9
# 2               3.2               3.3               3.2               3.1
#
#    HousingPI25_1984  HousingPI25_1985  HousingPI25_1986  ...  \
# 0               2.5               2.4               2.3  ...
# 1               2.7               2.6               2.6  ...
# 2               3.0               3.0               3.0  ...
#
#    HousingPI25_2015  HousingPI25_2016  HousingPI25_2017  HousingPI25_2018  \
# 0               4.0               4.1               4.4               4.6
# 1               3.3               3.2               3.3               3.3
# 2               3.0               3.1               3.2               3.3
#
#    HousingPI25_2019  HousingPI25_2020  HousingPI25_2021  HousingPI25_2022  \
# 0               4.5               4.5               5.1               5.7
# 1               3.4               3.6               3.8               4.2
# 2               3.2               3.4               3.6               4.1
#
#    HousingPI25_2023  HousingPI25_2024
# 0               5.7               5.7
# 1               3.9               4.0
# 2               4.2               4.3
#
# [3 rows x 48 columns]

# %%
residence_df.head(3)
# Out:
#    Current_Residence_Code                          MSA_Name  \
# 0                   10180            Abilene, TX Metro Area
# 1                   10380  Aguadilla-Isabela, PR Metro Area
# 2                   10420              Akron, OH Metro Area
#
#    Current_Residence_Population  Current_Residence_Population_MOE  \
# 0                      169276.0                             377.0
# 1                      293250.0                             317.0
# 2                      696296.0                             554.0
#
#    Current_Residence_Nonmovers  Current_Residence_Nonmovers_MOE  \
# 0                     135412.0                           2025.0
# 1                     279448.0                           1303.0
# 2                     608350.0                           3673.0
#
#    Current_Residence_Movers_within_MSA  \
# 0                              18575.0
# 1                              10183.0
# 2                              56839.0
#
#    Current_Residence_Movers_within_MSA_MOE  \
# 0                                   1619.0
# 1                                   1196.0
# 2                                   3142.0
#
#    Current_Residence_Movers_different_MSA  \
# 0                                 10581.0
# 1                                  3385.0
# 2                                 25847.0
#
#    Current_Residence_Movers_different_MSA_MOE  Current_Residence_elsewhere_PR  \
# 0                                      1135.0                          3493.0
# 1                                       622.0                            62.0
# 2                                      1672.0                          3218.0
#
#    Current_Residence_elsewhere_PR_MOE  Current_Residence_Movers_abroad  \
# 0                               500.0                           1215.0
# 1                                65.0                            172.0
# 2                               520.0                           2042.0
#
#    Current_Residence_Movers_abroad_MOE
# 0                                439.0
# 1                                122.0
# 2                                513.0

# %%
# Step 1 : Already done loading datasets.

# Step 2: Set base
combined_df = criteria_df.copy()

# Step 3: Merge datasets
combined_df = combined_df.merge(
    hazard_df,
    how='left',
    left_on=join_keys['criteria'],
    right_on=join_keys['hazard'],
    suffixes=('', '_hazard')
)

combined_df = combined_df.merge(
    migration_df,
    how='left',
    left_on=join_keys['criteria'],
    right_on=join_keys['migration'],
    suffixes=('', '_migration')
)

combined_df = combined_df.merge(
    housing_df,
    how='left',
    left_on=join_keys['criteria'],
    right_on=join_keys['housing'],
    suffixes=('', '_housing')
)

combined_df = combined_df.merge(
    unemployment_df,
    how='left',
    left_on=join_keys['criteria'],
    right_on=join_keys['unemployment'],
    suffixes=('', '_unemployment')
)

combined_df = combined_df.merge(
    residence_df,
    how='left',
    left_on=join_keys['criteria'],
    right_on=join_keys['residence'],
    suffixes=('', '_residence')
)



# Step 4: Drop only non-criteria join keys
redundant_keys = [
    join_keys['hazard'],
    join_keys['migration'],
    join_keys['housing'],
    join_keys['unemployment'],
    join_keys['residence']
]
redundant_keys = [key for key in redundant_keys if key != join_keys['criteria']]

combined_df.drop(columns=redundant_keys, inplace=True, errors='ignore')

# Step 5: Reorder to put CBSA code first
cbsa_col = join_keys['criteria']
cols = combined_df.columns.tolist()
combined_df = combined_df[[cbsa_col] + [col for col in cols if col != cbsa_col]]

# Step 6: Preview
combined_df.head()
# Out:
#    Crosswalk2023_CBSA Code Crosswalk2023_CBSA Title Crosswalk2023_State Name  \
# 0                    10180              Abilene, TX                    Texas
# 1                    10380            Aguadilla, PR              Puerto Rico
# 2                    10420                Akron, OH                     Ohio
# 3                    10500               Albany, GA                  Georgia
# 4                    10540               Albany, OR                   Oregon
#
#    NRI_AVLN_EALPE  NRI_CFLD_EALPE  NRI_CWAV_EALPE  NRI_ERQK_EALPE  \
# 0         0.00000        0.000000   485441.029265    1.990667e+04
# 1         0.00000     1170.838964        0.000000    2.658766e+07
# 2         0.00000        0.000000   283878.596332    1.674568e+05
# 3         0.00000        0.000000        0.000000    1.601961e+05
# 4     36919.52184        0.000000     1485.855905    1.342393e+07
#
#    NRI_HAIL_EALPE  NRI_HWAV_EALPE  NRI_HRCN_EALPE  ...  \
# 0   483001.071482    1.375110e+06    2.751964e+03  ...
# 1     3692.194710    0.000000e+00    5.023007e+06  ...
# 2   118503.301890    4.250440e+05    9.718143e+03  ...
# 3    88644.910173    4.045832e+05    2.234962e+05  ...
# 4    28589.341968    2.023923e+04    0.000000e+00  ...
#
#    Current_Residence_Nonmovers  Current_Residence_Nonmovers_MOE  \
# 0                     135412.0                           2025.0
# 1                     279448.0                           1303.0
# 2                     608350.0                           3673.0
# 3                     120553.0                           2126.0
# 4                     107624.0                           1539.0
#
#    Current_Residence_Movers_within_MSA  \
# 0                              18575.0
# 1                              10183.0
# 2                              56839.0
# 3                              17006.0
# 4                               9954.0
#
#    Current_Residence_Movers_within_MSA_MOE  \
# 0                                   1619.0
# 1                                   1196.0
# 2                                   3142.0
# 3                                   1757.0
# 4                                   1219.0
#
#    Current_Residence_Movers_different_MSA  \
# 0                                 10581.0
# 1                                  3385.0
# 2                                 25847.0
# 3                                  5505.0
# 4                                  7173.0
#
#    Current_Residence_Movers_different_MSA_MOE  Current_Residence_elsewhere_PR  \
# 0                                      1135.0                          3493.0
# 1                                       622.0                            62.0
# 2                                      1672.0                          3218.0
# 3                                       840.0                          1979.0
# 4                                       969.0                           736.0
#
#    Current_Residence_elsewhere_PR_MOE  Current_Residence_Movers_abroad  \
# 0                               500.0                           1215.0
# 1                                65.0                            172.0
# 2                               520.0                           2042.0
# 3                               434.0                            431.0
# 4                               259.0                            361.0
#
#    Current_Residence_Movers_abroad_MOE
# 0                                439.0
# 1                                122.0
# 2                                513.0
# 3                                308.0
# 4                                181.0
#
# [5 rows x 172 columns]

# %%
combined_df.to_csv(f'../../data/final/final_data_{crosswalk_version}.csv', index=False)

# %%
combined_df
# Out:
#      Crosswalk2023_CBSA Code Crosswalk2023_CBSA Title  \
# 0                      10180              Abilene, TX
# 1                      10380            Aguadilla, PR
# 2                      10420                Akron, OH
# 3                      10500               Albany, GA
# 4                      10540               Albany, OR
# ..                       ...                      ...
# 388                    49420               Yakima, WA
# 389                    49620         York-Hanover, PA
# 390                    49660    Youngstown-Warren, OH
# 391                    49700            Yuba City, CA
# 392                    49740                 Yuma, AZ
#
#     Crosswalk2023_State Name  NRI_AVLN_EALPE  NRI_CFLD_EALPE  NRI_CWAV_EALPE  \
# 0                      Texas        0.000000        0.000000    4.854410e+05
# 1                Puerto Rico        0.000000     1170.838964    0.000000e+00
# 2                       Ohio        0.000000        0.000000    2.838786e+05
# 3                    Georgia        0.000000        0.000000    0.000000e+00
# 4                     Oregon    36919.521840        0.000000    1.485856e+03
# ..                       ...             ...             ...             ...
# 388               Washington   168354.956650        0.000000    1.635637e+06
# 389             Pennsylvania        0.000000        0.000000    3.291121e+05
# 390                     Ohio        0.000000        0.000000    3.043149e+06
# 391               California    61532.536375        0.000000    0.000000e+00
# 392                  Arizona        0.000000        0.000000    0.000000e+00
#
#      NRI_ERQK_EALPE  NRI_HAIL_EALPE  NRI_HWAV_EALPE  NRI_HRCN_EALPE  ...  \
# 0      1.990667e+04   483001.071482    1.375110e+06    2.751964e+03  ...
# 1      2.658766e+07     3692.194710    0.000000e+00    5.023007e+06  ...
# 2      1.674568e+05   118503.301890    4.250440e+05    9.718143e+03  ...
# 3      1.601961e+05    88644.910173    4.045832e+05    2.234962e+05  ...
# 4      1.342393e+07    28589.341968    2.023923e+04    0.000000e+00  ...
# ..              ...             ...             ...             ...  ...
# 388    6.451273e+06    15375.668773    1.456925e+05    0.000000e+00  ...
# 389    1.178405e+05     2175.367687    8.589427e+05    4.652846e+05  ...
# 390    1.030401e+05    67028.229971    9.982039e+05    2.075168e+04  ...
# 391    7.949410e+06    13702.433003    1.572410e+06    0.000000e+00  ...
# 392    1.044114e+07      233.288082    6.061415e+05    3.714090e+01  ...
#
#      Current_Residence_Nonmovers  Current_Residence_Nonmovers_MOE  \
# 0                       135412.0                           2025.0
# 1                       279448.0                           1303.0
# 2                       608350.0                           3673.0
# 3                       120553.0                           2126.0
# 4                       107624.0                           1539.0
# ..                           ...                              ...
# 388                     213587.0                           2394.0
# 389                     391028.0                           2739.0
# 390                     473891.0                           2365.0
# 391                     146224.0                           1918.0
# 392                     172584.0                           2634.0
#
#      Current_Residence_Movers_within_MSA  \
# 0                                18575.0
# 1                                10183.0
# 2                                56839.0
# 3                                17006.0
# 4                                 9954.0
# ..                                   ...
# 388                              25450.0
# 389                              31693.0
# 390                              40928.0
# 391                              15079.0
# 392                              20504.0
#
#      Current_Residence_Movers_within_MSA_MOE  \
# 0                                     1619.0
# 1                                     1196.0
# 2                                     3142.0
# 3                                     1757.0
# 4                                     1219.0
# ..                                       ...
# 388                                   2212.0
# 389                                   2107.0
# 390                                   2089.0
# 391                                   1576.0
# 392                                   1995.0
#
#      Current_Residence_Movers_different_MSA  \
# 0                                   10581.0
# 1                                    3385.0
# 2                                   25847.0
# 3                                    5505.0
# 4                                    7173.0
# ..                                      ...
# 388                                  6582.0
# 389                                 17697.0
# 390                                 12533.0
# 391                                  8023.0
# 392                                 10640.0
#
#      Current_Residence_Movers_different_MSA_MOE  \
# 0                                        1135.0
# 1                                         622.0
# 2                                        1672.0
# 3                                         840.0
# 4                                         969.0
# ..                                          ...
# 388                                       944.0
# 389                                      1597.0
# 390                                      1110.0
# 391                                       920.0
# 392                                      1196.0
#
#      Current_Residence_elsewhere_PR  Current_Residence_elsewhere_PR_MOE  \
# 0                            3493.0                               500.0
# 1                              62.0                                65.0
# 2                            3218.0                               520.0
# 3                            1979.0                               434.0
# 4                             736.0                               259.0
# ..                              ...                                 ...
# 388                          1147.0                               321.0
# 389                          1155.0                               319.0
# 390                          4075.0                               676.0
# 391                          1374.0                               446.0
# 392                          1563.0                               424.0
#
#      Current_Residence_Movers_abroad  Current_Residence_Movers_abroad_MOE
# 0                             1215.0                                439.0
# 1                              172.0                                122.0
# 2                             2042.0                                513.0
# 3                              431.0                                308.0
# 4                              361.0                                181.0
# ..                               ...                                  ...
# 388                            759.0                                291.0
# 389                           1622.0                                382.0
# 390                            985.0                                286.0
# 391                           1077.0                                392.0
# 392                           3760.0                               1131.0
#
# [393 rows x 172 columns]
